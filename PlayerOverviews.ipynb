# %%
import pandas as pd

# %%
years = [str(year) for year in range(1953,1974)]
impacts = pd.DataFrame()
for year in years:
    impact = pd.read_excel('InformedImpact/'+year+'impactInformed.xlsx')
    impact['year']=str(year)
    if len(impacts) == 0:
        impacts = impact.copy()
    else:
        impacts=pd.concat([impacts, impact], axis=0)
impacts
# Out:
#              Player       Impact    Minutes  AvgMinutes  Games  OldImpact  \
# 0      Bobby Wanzer    80.972059   1.687500    0.843750      2     0.6206
# 1         Joe Fulks    44.988839   2.937500    0.734375      4     1.3786
# 2         Bob Cousy    23.844345  19.711085    0.857004     23    21.7289
# 3       Alex Hannum    52.210898   0.687500    0.343750      2     0.3064
# 4     Dolph Schayes    20.711787   4.229167    0.845833      5     2.0027
# ..              ...          ...        ...         ...    ...        ...
# 177    Mike Ratliff  -288.915200   1.787736    0.198637      9  -288.9152
# 178  Paul McCracken  -271.969800   1.208333    0.302083      4  -271.9698
# 179   Dennis Awtrey -2159.061605   0.062500    0.062500      1     0.1384
# 180      Dick Gibbs  -677.553217   2.041667    0.226852      9     0.0731
# 181      Bob Lanier  -304.947800  13.316431    0.887762     15  -304.9478
#
#      ImpactPerGame  ImpactPerGameScaled  ImpactScaled  year
# ...

# %%
player = 'Wilt Chamberlain'
impacts[impacts.Player == player]
# Out:
#                Player      Impact    Minutes  AvgMinutes  Games  OldImpact  \
# 6    Wilt Chamberlain   48.000000  13.395833    0.956845     14    48.0000
# 39   Wilt Chamberlain  126.376400  26.395833    0.977623     27     0.0548
# 52   Wilt Chamberlain    5.801077  24.000000    1.000000     24     0.0004
# 54   Wilt Chamberlain    2.984295  77.437500    0.980222     79    -0.1158
# 15   Wilt Chamberlain    9.369663  75.274764    0.952845     79     0.4693
# 49   Wilt Chamberlain    1.746181  53.841195    0.928296     58     0.0231
# 3    Wilt Chamberlain   22.420144  66.937500    0.984375     68     5.7855
# 116  Wilt Chamberlain   -9.357690  67.803459    0.941715     72    -0.0197
# 2    Wilt Chamberlain   20.838984  56.437500    0.973060     58    -0.3880
# 30   Wilt Chamberlain    3.264933  48.101022    0.925020     52     0.0078
# 45   Wilt Chamberlain    5.246244  10.416667    0.868056     12     0.5196
# ...

# %%
player = 'Bill Russell'
impacts[impacts.Player == player]
# Out:
#            Player      Impact    Minutes  AvgMinutes  Games  OldImpact  \
# 32   Bill Russell    0.697800  16.093879    0.699734     23     0.6978
# 74   Bill Russell  -11.779677  29.333333    0.792793     37    -7.8773
# 11   Bill Russell   45.908479  30.695362    0.877010     35     0.3388
# 4    Bill Russell   54.326049  35.323276    0.883082     40     0.0255
# 45   Bill Russell  121.535977  40.166667    0.912879     44     0.0412
# 39   Bill Russell   15.120076  36.333333    0.931624     39     0.0010
# 16   Bill Russell   22.641801  45.922563    0.937195     49     0.0766
# 17   Bill Russell    8.058568  50.854167    0.924621     55     0.0162
# 107  Bill Russell   -6.811152  47.924528    0.904236     53    -0.1032
# 27   Bill Russell    6.177412  52.041667    0.897270     58     0.1114
# 125  Bill Russell  -17.571330  47.866786    0.825289     58    -0.4599
# 33   Bill Russell    7.828371  35.261792    0.766561     46     0.0021
# ...

# %%
player = 'Jerry West'
impacts[impacts.Player == player]
# Out:
#          Player      Impact    Minutes  AvgMinutes  Games  OldImpact  \
# 16   Jerry West  326.860100   8.505747    0.773250     11   326.8601
# 3    Jerry West  149.277508  12.267689    0.817846     15     0.0005
# 44   Jerry West    7.344353  12.958333    0.809896     16    -0.0001
# 32   Jerry West    2.273952  22.555425    0.835386     27     0.0398
# 114  Jerry West  -27.201011  27.125000    0.847656     32    -4.5172
# 6    Jerry West   19.077388  33.182390    0.850831     39     0.0258
# 120  Jerry West  -12.538228  26.769654    0.836552     32    -0.0330
# 5    Jerry West   22.885170  22.866515    0.788501     29     0.1985
# 121  Jerry West   -5.307917  25.163522    0.811727     31    -0.0100
# 8    Jerry West   19.479050  61.333726    0.863855     71     0.6524
# 105  Jerry West    0.023000  17.710299    0.885515     20     0.0230
# 197  Jerry West  -26.431800  16.916667    0.805556     21   -26.4318
# 95   Jerry West    0.010900  15.124607    0.756230     20     0.0109
#
# ...

# %%
player = 'Bob Pettit'
impacts[impacts.Player == player]
# Out:
#          Player      Impact    Minutes  AvgMinutes  Games  OldImpact  \
# 39   Bob Pettit   -0.474200   3.958333    0.791667      5    -0.4742
# 90   Bob Pettit -107.339013  10.541667    0.810897     13   -87.6333
# 13   Bob Pettit   26.545638  16.075838    0.730720     22     0.0007
# 80   Bob Pettit  -18.254344   7.166667    0.796296      9    -0.0228
# 16   Bob Pettit   28.852632  29.670597    0.824183     36     0.1422
# 3    Bob Pettit   60.784112   4.937500    0.822917      6     0.0926
# 37   Bob Pettit  161.875421  31.942827    0.819047     39     0.0438
# 22   Bob Pettit   40.646118  50.981132    0.864087     59    -0.0008
# 87   Bob Pettit   -6.208762  52.854167    0.800821     66    -0.0021
# 112  Bob Pettit  -35.786303  57.400659    0.856726     67    -1.0073
# 33   Bob Pettit    6.690081  32.479167    0.721759     45     0.0052
#
#      ImpactPerGame  ImpactPerGameScaled  ImpactScaled  year
# 39       -0.375408             0.312350      0.308249  1955
# ...

# %%
player = 'Bob Cousy'
impacts[impacts.Player == player]
# Out:
#        Player      Impact    Minutes  AvgMinutes  Games  OldImpact  \
# 2   Bob Cousy   23.844345  19.711085    0.857004     23    21.7289
# 29  Bob Cousy    2.376412  20.789240    0.799586     26     0.0039
# 63  Bob Cousy  -16.942658  15.401730    0.770086     20    -6.3921
# 14  Bob Cousy   48.436138  27.056211    0.795771     34     0.1682
# 26  Bob Cousy    5.907322  21.605902    0.720197     30     0.0078
# 69  Bob Cousy   -7.013391  23.250000    0.704545     33    -0.1225
# 71  Bob Cousy  -14.740701  25.667060    0.733345     35    -0.3892
# 41  Bob Cousy    1.287867  23.580189    0.714551     33     0.0069
# 7   Bob Cousy  481.331698  23.727987    0.659111     36   154.5155
# 44  Bob Cousy   18.435104  19.629717    0.577345     34     0.0001
# 36  Bob Cousy   17.141298  21.367531    0.534188     40     0.0538
# 58  Bob Cousy   29.784300   0.704741    0.100677      7    29.7843
#
#     ImpactPerGame  ImpactPerGameScaled  ImpactScaled  year
# ...

# %%
player = 'Bill Sharman'
impacts[impacts.Player == player]
# Out:
#            Player      Impact    Minutes  AvgMinutes  Games  OldImpact  \
# 16   Bill Sharman    7.259747  15.346305    0.667231     23     0.0427
# 106  Bill Sharman  -47.044536  17.178649    0.660717     26    -0.8740
# 87   Bill Sharman  -67.119486  12.354953    0.726762     17    -0.0575
# 21   Bill Sharman   36.185403  24.793632    0.751322     33     0.0080
# 72   Bill Sharman   -5.907995  22.101890    0.712964     31     0.0047
# 81   Bill Sharman  -26.056070  20.229167    0.697557     29    -0.5613
# 39   Bill Sharman   14.097356  25.038129    0.676706     37     0.0375
# 76   Bill Sharman   -7.742698  16.875000    0.544355     31    -0.0540
# 19   Bill Sharman  397.005044  15.328616    0.510954     30     6.5137
#
#      ImpactPerGame  ImpactPerGameScaled  ImpactScaled  year
# 16        4.843925             0.399049      0.404559  1953
# 106     -31.083137            -1.405861     -1.313480  1954
# 87      -48.779887            -1.059205     -0.575432  1955
# ...

# %%
player = 'H','@','N'
impacts[impacts.Player.isin(player)]
# Out:
#     Player  Impact  Minutes  AvgMinutes  Games  OldImpact  ImpactPerGame  \
# 14       @  5.0267     28.0         1.0     28     5.0267         5.0267
# 44       N  0.2820      2.0         1.0      2     0.2820         0.2820
# 99       H -5.4044     28.0         1.0     28    -5.4044        -5.4044
# 18       @  6.3447     66.0         1.0     66     6.3447         6.3447
# 46       N -0.0494     12.0         1.0     12    -0.0494        -0.0494
# ..     ...     ...      ...         ...    ...        ...            ...
# 76       @  5.9252    161.0         1.0    161     5.9252         5.9252
# 93       H  2.7729    169.0         1.0    169     2.7729         2.7729
# 76       @  1.9977    157.0         1.0    157     1.9977         1.9977
# 89       H  0.0505    153.0         1.0    153     0.0505         0.0505
# 126      N -2.1805     24.0         1.0     24    -2.1805        -2.1805
#
#      ImpactPerGameScaled  ImpactScaled  year
# 14              0.418460      0.241911  1953
# ...
